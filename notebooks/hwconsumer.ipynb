# %%
from kafka import KafkaConsumer
import json

server = 'localhost:9092'
topic_name = 'green-trips'

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    consumer_timeout_ms=3000,  # stops after 3 seconds of no new messages
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

total = 0
count = 0

for message in consumer:
    ride = message.value
    total += 1
    if ride['trip_distance'] > 5.0:
        count += 1

print(f"Total messages in topic: {total}")
print(f"Trips with distance > 5.0: {count}")
# Out:
# Total messages in topic: 49416
# Trips with distance > 5.0: 8506
# If producer ran multiple times, answer per run: 1.0
